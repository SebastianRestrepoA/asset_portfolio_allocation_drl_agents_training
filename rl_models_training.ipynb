# %%
import pandas as pd
import numpy as np
import ta
from ta import add_all_ta_features
from pandas_datareader import data as pdr
from sklearn import preprocessing
from keras.models import Model, Sequential
from keras.layers import Input
from keras.layers import LSTM
from keras.layers import Dense, Activation
from keras.layers import RepeatVector
from keras.layers import TimeDistributed
from keras.utils import plot_model
from keras import regularizers, optimizers

# %%
# Load the whole data set
data = pd.read_csv('./datasets/data.csv')
list_of_stocks = ['JNJ', 'KO', 'PG', 'TRV', 'MRK', 'IBM', 'VZ', 'WMT', 'MMM', 'XOM',
'DIS', 'MCD', 'MSFT', 'CSCO', 'PFE', 'V', 'HD', 'CAT', 'NKE', 'JPM']

# %%
data = data[data['tic'].isin(list_of_stocks)]

# %%
data.tic.unique()
# Out:
# array(['MSFT', 'JPM', 'V', 'PG', 'NKE', 'DIS', 'HD', 'WMT', 'IBM', 'MRK',
#        'KO', 'CAT', 'TRV', 'JNJ', 'MCD', 'VZ', 'CSCO', 'XOM', 'MMM',
#        'PFE'], dtype=object)

# %%
# Define a Function for adding technical indicators

def add_features(data, feature_list, short_names):
    """
    Function to add technical indicators for features
    -Takes in a dataset with Open, High, Low, Close and Volume
    -Also takes in a list of the technical indicators to be added 
     as well as a list of the shortened indicator names
    """
    
    # list of column names to filter the features
    data_col_names = list(data.columns)
    filter_names = data_col_names + feature_list
    col_rename = data_col_names +  short_names
    
    # Add technical indicators using the ta Library
    data = add_all_ta_features(data, open="open", high="high", 
    low="low", close="close", volume="volume") 
    
    # Filter the Indicators with the required features
    data = data[filter_names]
    data.columns = col_rename # rename the columns to use shortened indicator names
    data = data.dropna()
    
    return data

# %%
# List of Features to add
feature_list= ['volatility_atr','volatility_bbw','volume_obv','volume_cmf',
               'trend_macd', 'trend_adx', 'trend_sma_fast', 
               'trend_ema_fast', 'trend_cci', 'momentum_rsi']

# Short names of the features
short_names = ['atr', 'bbw','obv','cmf','macd', 'adx', 'sma', 'ema', 'cci', 'rsi']

#feature_list= ['volatility_atr','volatility_bbw','volume_obv','volume_cmf','trend_macd']

# Short names of the features
#short_names = ['atr', 'bbw','obv','cmf','macd']

# %%
# Add Indicators to our dataset
data_with_features = data.copy()

data_with_features = add_features(data_with_features, feature_list, short_names)
data_with_features.head()
# Out:
# c:\Users\Usuario\Documents\deep_learning_asset_portfolio_management\env\lib\site-packages\ta\trend.py:780: RuntimeWarning: invalid value encountered in double_scalars
#   dip[idx] = 100 * (self._dip[idx] / value)
# c:\Users\Usuario\Documents\deep_learning_asset_portfolio_management\env\lib\site-packages\ta\trend.py:785: RuntimeWarning: invalid value encountered in double_scalars
#   din[idx] = 100 * (self._din[idx] / value)
#             date       open       high        low      close      volume  \
# 3046  2009-02-06  19.160000  19.930000  19.059999  14.961291  86746000.0
# 3047  2009-02-09  19.639999  19.770000  19.260000  14.793870  52196400.0
# 3048  2009-02-10  19.250000  19.799999  18.700001  14.306821  83953200.0
# 3049  2009-02-11  18.940001  19.490000  18.920000  14.618835  58599000.0
# 3050  2009-02-12  18.969999  19.320000  18.540001  14.656886  75323200.0
#
#        tic       atr        bbw          obv        cmf      macd        adx  \
# 3046  MSFT  4.796015  19.908847  666119400.0 -11.968562 -0.134506   0.000000
# 3047  MSFT  4.797284  19.824320  613923000.0 -12.195378 -0.069528   0.000000
# 3048  MSFT  4.818169  19.364400  529969800.0 -11.818747 -0.056679  19.813499
# 3049  MSFT  4.854670  18.618891  588568800.0 -11.652975 -0.021077  18.755084
# 3050  MSFT  4.839319  18.760384  663892000.0 -11.492100  0.010092  18.256305
#
#             sma        ema        cci        rsi
# 3046  13.697392  14.104219  83.765563  57.740745
# 3047  13.845153  14.210319  82.279873  55.710462
# 3048  13.946619  14.225165  54.030264  50.182408
# 3049  14.046818  14.285730  65.615975  53.374297
# 3050  14.148285  14.342831  50.931498  53.763363

# %%
feature_list = list(data_with_features.columns)[7:]
feature_list
# Out:
# ['atr', 'bbw', 'obv', 'cmf', 'macd', 'adx', 'sma', 'ema', 'cci', 'rsi']

# %%
def add_cov_matrix(df):
    """
    Function to add Coveriance Matrices as part of the defined states
    """
    # Sort the data and index by date and tic
    df=df.sort_values(['date','tic'],ignore_index=True) 
    df.index = df.date.factorize()[0]
    
    cov_list = [] # create empty list for storing coveriance matrices at each time step
    
    # look back for constructing the coveriance matrix is one year
    lookback=252
    for i in range(lookback,len(df.index.unique())):
        data_lookback = df.loc[i-lookback:i,:]
        price_lookback=data_lookback.pivot_table(index = 'date',columns = 'tic', values = 'close')
        return_lookback = price_lookback.pct_change().dropna()
        covs = return_lookback.cov().values 
        covs = covs#/covs.max()
        cov_list.append(covs)
        
    df_cov = pd.DataFrame({'date':df.date.unique()[lookback:],'cov_list':cov_list})
    df = df.merge(df_cov, on='date')
    df = df.sort_values(['date','tic']).reset_index(drop=True)
    
    return df

# %%
# Add Covariance Matrices to our dataset
data_with_features_covs = data_with_features.copy()
data_with_features_covs = add_cov_matrix(data_with_features_covs)
df = data_with_features_covs

# %%
# Get the list of all the features
features_list = list(df.columns)[7:-1]
print(features_list)
# construct a data frame of features
features_df = df[features_list]
features_df.index = df['date']
features_df.head()
# Out:
# ['atr', 'bbw', 'obv', 'cmf', 'macd', 'adx', 'sma', 'ema', 'cci', 'rsi']
#                   atr        bbw           obv        cmf      macd  \
# date
# 2009-12-31  16.411522   4.599234  1.751191e+10 -35.806296  0.044336
# 2009-12-31   6.172343   4.656155  2.310719e+10 -36.494340  0.060804
# 2009-12-31   4.433756  10.239793  1.007232e+10 -17.293213  0.566996
# 2009-12-31   6.844032   7.539178  1.128392e+10 -30.420664  0.374300
# 2009-12-31  40.081142   5.281060  1.315387e+10 -68.591339  0.972473
#
#                   adx        sma        ema         cci        rsi
# date
# 2009-12-31  10.020770  41.918410  41.881607  -50.733730  44.302408
# 2009-12-31   8.984294  17.752903  17.857885   57.386845  53.264455
# 2009-12-31  28.281289  28.071835  27.909763   77.608718  62.419287
# 2009-12-31  19.200721  22.384340  22.300831   58.112405  58.501256
# 2009-12-31  14.028633  90.417915  90.721556  118.276233  59.004777

# %%
print(features_df.shape)
print(df.shape)
# Out:
# (55380, 10)
# (55380, 18)

# %%
features_array = np.array(features_df)
features_scaler = preprocessing.MinMaxScaler()
features_normalised = features_scaler.fit_transform(features_array)
features_normalised.shape
# Out:
# (55380, 10)

# %%
# rescale the features array
features_normalised = features_normalised.reshape(-1,20,10)

# %%
# define model
model = Sequential()
model.add(LSTM(4, activation='relu', input_shape=(20,10)))
model.add(RepeatVector(20))
model.add(LSTM(100, activation='relu', return_sequences=True))
model.add(TimeDistributed(Dense(10)))
model.compile(optimizer='adam', loss='mse')

# %%
# fit model
model.fit(features_normalised, features_normalised, epochs=100, verbose=1)
plot_model(model, show_shapes=True, to_file='./results/reconstruct_lstm_autoencoder.png')
# Out:
# Epoch 1/100
# 87/87 [==============================] - 3s 15ms/step - loss: 0.0595
# Epoch 2/100
# 87/87 [==============================] - 1s 14ms/step - loss: 0.0230
# Epoch 3/100
# 87/87 [==============================] - 1s 13ms/step - loss: 0.0188
# Epoch 4/100
# 87/87 [==============================] - 1s 13ms/step - loss: 0.0175
# Epoch 5/100
# 87/87 [==============================] - 1s 13ms/step - loss: 0.0167
# Epoch 6/100
# 87/87 [==============================] - 1s 14ms/step - loss: 0.0159
# Epoch 7/100
# 87/87 [==============================] - 1s 14ms/step - loss: 0.0146
# Epoch 8/100
# 87/87 [==============================] - 1s 13ms/step - loss: 0.0125
# Epoch 9/100
# 87/87 [==============================] - 1s 14ms/step - loss: 0.0114
# Epoch 10/100
# 87/87 [==============================] - 1s 13ms/step - loss: 0.0107
# Epoch 11/100
# 87/87 [==============================] - 1s 13ms/step - loss: 0.0101
# Epoch 12/100
# 87/87 [==============================] - 1s 13ms/step - loss: 0.0097
# Epoch 13/100
# 87/87 [==============================] - 1s 13ms/step - loss: 0.0093
# Epoch 14/100
# 87/87 [==============================] - 1s 13ms/step - loss: 0.0088
# Epoch 15/100
# 87/87 [==============================] - 1s 15ms/step - loss: 0.0085
# Epoch 16/100
# 87/87 [==============================] - 1s 14ms/step - loss: 0.0082
# Epoch 17/100
# 87/87 [==============================] - 1s 14ms/step - loss: 0.0078
# Epoch 18/100
# 87/87 [==============================] - 1s 13ms/step - loss: 0.0075
# Epoch 19/100
# 87/87 [==============================] - 1s 13ms/step - loss: 0.0070
# Epoch 20/100
# 87/87 [==============================] - 1s 14ms/step - loss: 0.0064
# Epoch 21/100
# 87/87 [==============================] - 2s 19ms/step - loss: 0.0059
# Epoch 22/100
# 87/87 [==============================] - 1s 15ms/step - loss: 0.0057
# Epoch 23/100
# 87/87 [==============================] - 1s 14ms/step - loss: 0.0056
# Epoch 24/100
# 87/87 [==============================] - 1s 14ms/step - loss: 0.0055
# Epoch 25/100
# 87/87 [==============================] - 1s 14ms/step - loss: 0.0055
# Epoch 26/100
# 87/87 [==============================] - 1s 15ms/step - loss: 0.0054
# Epoch 27/100
# 87/87 [==============================] - 1s 14ms/step - loss: 0.0053
# Epoch 28/100
# 87/87 [==============================] - 1s 14ms/step - loss: 0.0052
# Epoch 29/100
# 87/87 [==============================] - 1s 15ms/step - loss: 0.0052
# Epoch 30/100
# 87/87 [==============================] - 1s 13ms/step - loss: 0.0051
# Epoch 31/100
# 87/87 [==============================] - 1s 14ms/step - loss: 0.0051
# Epoch 32/100
# 87/87 [==============================] - 1s 15ms/step - loss: 0.0050
# Epoch 33/100
# 87/87 [==============================] - 1s 14ms/step - loss: 0.0049
# Epoch 34/100
# 87/87 [==============================] - 1s 14ms/step - loss: 0.0049
# Epoch 35/100
# 87/87 [==============================] - 1s 14ms/step - loss: 0.0049
# Epoch 36/100
# 87/87 [==============================] - 1s 17ms/step - loss: 0.0048
# Epoch 37/100
# 87/87 [==============================] - 1s 15ms/step - loss: 0.0048
# Epoch 38/100
# 87/87 [==============================] - 1s 14ms/step - loss: 0.0048
# Epoch 39/100
# 87/87 [==============================] - 1s 15ms/step - loss: 0.0047
# Epoch 40/100
# 87/87 [==============================] - 1s 15ms/step - loss: 0.0047
# Epoch 41/100
# 87/87 [==============================] - 1s 15ms/step - loss: 0.0047
# Epoch 42/100
# 87/87 [==============================] - 1s 15ms/step - loss: 0.0047
# Epoch 43/100
# 87/87 [==============================] - 1s 15ms/step - loss: 0.0046
# Epoch 44/100
# 87/87 [==============================] - 1s 15ms/step - loss: 0.0046
# Epoch 45/100
# 87/87 [==============================] - 1s 14ms/step - loss: 0.0046
# Epoch 46/100
# 87/87 [==============================] - 1s 15ms/step - loss: 0.0046
# Epoch 47/100
# 87/87 [==============================] - 1s 14ms/step - loss: 0.0046
# Epoch 48/100
# 87/87 [==============================] - 1s 15ms/step - loss: 0.0046
# Epoch 49/100
# 87/87 [==============================] - 1s 14ms/step - loss: 0.0046
# Epoch 50/100
# 87/87 [==============================] - 1s 14ms/step - loss: 0.0045
# Epoch 51/100
# 87/87 [==============================] - 1s 14ms/step - loss: 0.0046
# Epoch 52/100
# 87/87 [==============================] - 1s 14ms/step - loss: 0.0045
# Epoch 53/100
# 87/87 [==============================] - 1s 15ms/step - loss: 0.0045
# Epoch 54/100
# 87/87 [==============================] - 1s 14ms/step - loss: 0.0045
# Epoch 55/100
# 87/87 [==============================] - 1s 15ms/step - loss: 0.0045
# Epoch 56/100
# 87/87 [==============================] - 1s 16ms/step - loss: 0.0045
# Epoch 57/100
# 87/87 [==============================] - 1s 15ms/step - loss: 0.0045
# Epoch 58/100
# 87/87 [==============================] - 1s 14ms/step - loss: 0.0045
# Epoch 59/100
# 87/87 [==============================] - 1s 15ms/step - loss: 0.0044
# Epoch 60/100
# 87/87 [==============================] - 1s 16ms/step - loss: 0.0044
# Epoch 61/100
# 87/87 [==============================] - 1s 14ms/step - loss: 0.0044
# Epoch 62/100
# 87/87 [==============================] - 1s 14ms/step - loss: 0.0044
# Epoch 63/100
# 87/87 [==============================] - 1s 14ms/step - loss: 0.0044
# Epoch 64/100
# 87/87 [==============================] - 1s 14ms/step - loss: 0.0044
# Epoch 65/100
# 87/87 [==============================] - 1s 15ms/step - loss: 0.0044
# Epoch 66/100
# 87/87 [==============================] - 1s 15ms/step - loss: 0.0044
# Epoch 67/100
# 87/87 [==============================] - 1s 15ms/step - loss: 0.0044
# Epoch 68/100
# 87/87 [==============================] - 1s 14ms/step - loss: 0.0044
# Epoch 69/100
# 87/87 [==============================] - 1s 14ms/step - loss: 0.0044
# Epoch 70/100
# 87/87 [==============================] - 1s 15ms/step - loss: 0.0044
# Epoch 71/100
# 87/87 [==============================] - 1s 14ms/step - loss: 0.0044
# Epoch 72/100
# 87/87 [==============================] - 1s 15ms/step - loss: 0.0044
# Epoch 73/100
# 87/87 [==============================] - 1s 16ms/step - loss: 0.0043
# Epoch 74/100
# 87/87 [==============================] - 1s 14ms/step - loss: 0.0043
# Epoch 75/100
# 87/87 [==============================] - 1s 15ms/step - loss: 0.0043
# Epoch 76/100
# 87/87 [==============================] - 1s 15ms/step - loss: 0.0043
# Epoch 77/100
# 87/87 [==============================] - 1s 14ms/step - loss: 0.0044
# Epoch 78/100
# 87/87 [==============================] - 1s 14ms/step - loss: 0.0043
# Epoch 79/100
# 87/87 [==============================] - 1s 14ms/step - loss: 0.0043
# Epoch 80/100
# 87/87 [==============================] - 1s 16ms/step - loss: 0.0043
# Epoch 81/100
# 87/87 [==============================] - 1s 14ms/step - loss: 0.0043
# Epoch 82/100
# 87/87 [==============================] - 1s 15ms/step - loss: 0.0043
# Epoch 83/100
# 87/87 [==============================] - 1s 14ms/step - loss: 0.0043
# Epoch 84/100
# 87/87 [==============================] - 1s 14ms/step - loss: 0.0043
# Epoch 85/100
# 87/87 [==============================] - 1s 14ms/step - loss: 0.0043
# Epoch 86/100
# 87/87 [==============================] - 1s 15ms/step - loss: 0.0043
# Epoch 87/100
# 87/87 [==============================] - 1s 14ms/step - loss: 0.0043
# Epoch 88/100
# 87/87 [==============================] - 1s 14ms/step - loss: 0.0043
# Epoch 89/100
# 87/87 [==============================] - 1s 14ms/step - loss: 0.0043
# Epoch 90/100
# 87/87 [==============================] - 1s 14ms/step - loss: 0.0043
# Epoch 91/100
# 87/87 [==============================] - 1s 14ms/step - loss: 0.0043
# Epoch 92/100
# 87/87 [==============================] - 1s 14ms/step - loss: 0.0043
# Epoch 93/100
# 87/87 [==============================] - 1s 16ms/step - loss: 0.0043
# Epoch 94/100
# 87/87 [==============================] - 1s 14ms/step - loss: 0.0042
# Epoch 95/100
# 87/87 [==============================] - 1s 15ms/step - loss: 0.0042
# Epoch 96/100
# 87/87 [==============================] - 1s 14ms/step - loss: 0.0042
# Epoch 97/100
# 87/87 [==============================] - 1s 14ms/step - loss: 0.0042
# Epoch 98/100
# 87/87 [==============================] - 1s 14ms/step - loss: 0.0042
# Epoch 99/100
# 87/87 [==============================] - 1s 16ms/step - loss: 0.0042
# Epoch 100/100
# 87/87 [==============================] - 1s 15ms/step - loss: 0.0042
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %%
model.summary()

# %%
# connect the encoder LSTM as the output layer
model_feature = Model(inputs=model.inputs, outputs=model.layers[1].output)
plot_model(model_feature, show_shapes=True, show_layer_names=True, to_file='./results/lstm_encoder.png')
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %%
# get the feature vector for the input sequence
yhat = model_feature.predict(features_normalised)
print(yhat.shape)
# Out:
# 87/87 [==============================] - 0s 3ms/step
# (2769, 20, 4)

# %%
# reshape the vector
features_reduced = yhat.reshape(-1,4)

# %%
# Copy original data frame and drop the original features
df_reduced = df.copy()
df_reduced = df_reduced.drop(features_list, axis=1)
df_reduced.head()
# Out:
#          date        open        high         low      close      volume  \
# 0  2009-12-31   57.599998   57.959999   56.990002  41.246521   3859700.0
# 1  2009-12-31   24.100000   24.170000   23.940001  17.903095  25208100.0
# 2  2009-12-31   32.270000   32.750000   32.220001  28.090706  19651700.0
# 3  2009-12-31   29.090000   29.370001   28.889999  22.307234   7437100.0
# 4  2009-12-31  132.410004  132.850006  130.750000  91.085335   4223400.0
#
#     tic                                           cov_list
# 0   CAT  [[0.0010639027833897088, 0.0004996216911050764...
# 1  CSCO  [[0.0010639027833897088, 0.0004996216911050764...
# 2   DIS  [[0.0010639027833897088, 0.0004996216911050764...
# 3    HD  [[0.0010639027833897088, 0.0004996216911050764...
# 4   IBM  [[0.0010639027833897088, 0.0004996216911050764...

# %%
# convert the reduced features to a data frame and merge with the original data frame
features_reduced_df = pd.DataFrame(features_reduced, columns=['f01','f02','f03','f04'])

# %%
df_reduced[['f01','f02','f03','f04']] = features_reduced_df[['f01','f02','f03','f04']]
df_reduced.head()
data_df = df_reduced.copy()

# %%
data_df
# Out:
#              date        open        high         low       close      volume  \
# 0      2009-12-31   57.599998   57.959999   56.990002   41.246521   3859700.0
# 1      2009-12-31   24.100000   24.170000   23.940001   17.903095  25208100.0
# 2      2009-12-31   32.270000   32.750000   32.220001   28.090706  19651700.0
# 3      2009-12-31   29.090000   29.370001   28.889999   22.307234   7437100.0
# 4      2009-12-31  132.410004  132.850006  130.750000   91.085335   4223400.0
# ...           ...         ...         ...         ...         ...         ...
# 55375  2020-12-30  138.949997  139.899994  138.850006  139.080002   1253800.0
# 55376  2020-12-30  216.000000  220.389999  215.649994  218.360001   8875100.0
# 55377  2020-12-30   58.830002   58.939999   58.060001   58.139999  18259800.0
# 55378  2020-12-30  144.880005  145.149994  143.940002  144.179993   6250400.0
# 55379  2020-12-30   41.330002   42.419998   41.270000   41.599998  23807300.0
#
#         tic                                           cov_list       f01  \
# 0       CAT  [[0.0010639027833897088, 0.0004996216911050764...  3.706141
# 1      CSCO  [[0.0010639027833897088, 0.0004996216911050764...  3.706141
# 2       DIS  [[0.0010639027833897088, 0.0004996216911050764...  3.706141
# 3        HD  [[0.0010639027833897088, 0.0004996216911050764...  3.706141
# 4       IBM  [[0.0010639027833897088, 0.0004996216911050764...  3.706141
# ...     ...                                                ...       ...
# 55375   TRV  [[0.0008016224880885106, 0.0005013084093293419...  7.507486
# 55376     V  [[0.0008016224880885106, 0.0005013084093293419...  7.507486
# 55377    VZ  [[0.0008016224880885106, 0.0005013084093293419...  7.507486
# 55378   WMT  [[0.0008016224880885106, 0.0005013084093293419...  7.507486
# 55379   XOM  [[0.0008016224880885106, 0.0005013084093293419...  7.507486
#
#             f02       f03       f04
# 0      1.601194  0.707921  2.725062
# 1      1.601194  0.707921  2.725062
# 2      1.601194  0.707921  2.725062
# 3      1.601194  0.707921  2.725062
# 4      1.601194  0.707921  2.725062
# ...         ...       ...       ...
# 55375  1.586209  0.935624  2.299339
# 55376  1.586209  0.935624  2.299339
# 55377  1.586209  0.935624  2.299339
# 55378  1.586209  0.935624  2.299339
# 55379  1.586209  0.935624  2.299339
#
# [55380 rows x 12 columns]

# %%
# Define the start and end dates for the train and test data

train_pct = 0.8 # percentage of train data
date_list = list(data_df.date.unique()) # List of dates in the data

date_list_len = len(date_list) # len of the date list
train_data_len = int(train_pct * date_list_len) # length of the train data

train_start_date = date_list[0]
train_end_date = date_list[train_data_len]

test_start_date = date_list[train_data_len+1]
test_end_date = date_list[-1]

# %%
print('Training Data: ', 'from ', train_start_date, ' to ', train_end_date)
print('Testing Data: ', 'from ', test_start_date, ' to ', test_end_date)
# Out:
# Training Data:  from  2009-12-31  to  2018-10-18
# Testing Data:  from  2018-10-19  to  2020-12-30

# %%
from utils import data_split

train_data = data_split(data_df, train_start_date, train_end_date)
test_data = data_split(data_df, test_start_date, test_end_date)
train_df = train_data.copy()
test_df = test_data.copy()

# %%
import env_portfolio
from env_portfolio import StockPortfolioEnv

import models
from models import DRLAgent

# %%
stock_dimension = len(train_df.tic.unique())
state_space = stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
weights_initial = [1/stock_dimension]*stock_dimension
tech_indicator_list = ['f01','f02','f03','f04']
# Out:
# Stock Dimension: 20, State Space: 20

# %%
env_kwargs = {
    "hmax": 500, 
    "initial_amount": 1000000, 
    "transaction_cost_pct": 0.001, 
    "state_space": state_space, 
    "stock_dim": stock_dimension, 
    "tech_indicator_list": tech_indicator_list, 
    "action_space": stock_dimension, 
    "reward_scaling": 0,
    'initial_weights': [1/stock_dimension]*stock_dimension
}

# %%
e_train_gym = StockPortfolioEnv(df = train_df, **env_kwargs)
env_train, _ = e_train_gym.get_sb_env()
print(type(env_train))
# Out:
# <class 'stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv'>
# c:\Users\Usuario\Documents\deep_learning_asset_portfolio_management\env\lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(

# %%
# initialize
agent = DRLAgent(env = env_train)

A2C_PARAMS = {"n_steps": 5, "ent_coef": 0.005, "learning_rate": 0.0002}
model_a2c = agent.get_model(model_name="a2c",model_kwargs = A2C_PARAMS)
# Out:
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0.0002}
# Using cpu device

# %%
trained_a2c = agent.train_model(model=model_a2c, 
                                tb_log_name='a2c',
                                total_timesteps=50000)
# Out:
# Logging to tensorboard_log/a2c\a2c_2
# ------------------------------------
# | time/                 |          |
# |    fps                | 378      |
# |    iterations         | 100      |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 500      |
# | train/                |          |
# |    entropy_loss       | -28.3    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 99       |
# |    policy_loss        | 1.04e+08 |
# |    std                | 0.997    |
# |    value_loss         | 1.59e+13 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 379      |
# |    iterations         | 200      |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 1000     |
# | train/                |          |
# |    entropy_loss       | -28.3    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 199      |
# |    policy_loss        | 1.5e+08  |
# |    std                | 0.996    |
# |    value_loss         | 3.79e+13 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 392      |
# |    iterations         | 300      |
# |    time_elapsed       | 3        |
# |    total_timesteps    | 1500     |
# | train/                |          |
# |    entropy_loss       | -28.3    |
# |    explained_variance | 2.38e-07 |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 299      |
# |    policy_loss        | 2.02e+08 |
# |    std                | 0.996    |
# |    value_loss         | 5.55e+13 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 402      |
# |    iterations         | 400      |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -28.3    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 399      |
# |    policy_loss        | 2.5e+08  |
# |    std                | 0.995    |
# |    value_loss         | 1.06e+14 |
# ------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3388843.8502931623
# Sharpe:  1.1274034916716411
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 401       |
# |    iterations         | 500       |
# |    time_elapsed       | 6         |
# |    total_timesteps    | 2500      |
# | train/                |           |
# |    entropy_loss       | -28.3     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 499       |
# |    policy_loss        | 1.02e+08  |
# |    std                | 0.994     |
# |    value_loss         | 1.43e+13  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 412      |
# |    iterations         | 600      |
# |    time_elapsed       | 7        |
# |    total_timesteps    | 3000     |
# | train/                |          |
# |    entropy_loss       | -28.3    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 599      |
# |    policy_loss        | 1.27e+08 |
# |    std                | 0.994    |
# |    value_loss         | 2.76e+13 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 405      |
# |    iterations         | 700      |
# |    time_elapsed       | 8        |
# |    total_timesteps    | 3500     |
# | train/                |          |
# |    entropy_loss       | -28.2    |
# |    explained_variance | 1.19e-07 |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 699      |
# |    policy_loss        | 1.79e+08 |
# |    std                | 0.993    |
# |    value_loss         | 4.77e+13 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 409      |
# |    iterations         | 800      |
# |    time_elapsed       | 9        |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -28.2    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 799      |
# |    policy_loss        | 2.1e+08  |
# |    std                | 0.993    |
# |    value_loss         | 6.79e+13 |
# ------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3302927.079697011
# Sharpe:  1.109078202509498
# =================================
# ------------------------------------
# | time/                 |          |
# |    fps                | 403      |
# |    iterations         | 900      |
# |    time_elapsed       | 11       |
# |    total_timesteps    | 4500     |
# | train/                |          |
# |    entropy_loss       | -28.3    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 899      |
# |    policy_loss        | 9.18e+07 |
# |    std                | 0.994    |
# |    value_loss         | 1.17e+13 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 408      |
# |    iterations         | 1000     |
# |    time_elapsed       | 12       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -28.3    |
# |    explained_variance | 5.96e-08 |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 999      |
# |    policy_loss        | 1.13e+08 |
# |    std                | 0.994    |
# |    value_loss         | 2.11e+13 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 409       |
# |    iterations         | 1100      |
# |    time_elapsed       | 13        |
# |    total_timesteps    | 5500      |
# | train/                |           |
# |    entropy_loss       | -28.3     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 1099      |
# |    policy_loss        | 1.56e+08  |
# |    std                | 0.994     |
# |    value_loss         | 4.08e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 408       |
# |    iterations         | 1200      |
# |    time_elapsed       | 14        |
# |    total_timesteps    | 6000      |
# | train/                |           |
# |    entropy_loss       | -28.2     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 1199      |
# |    policy_loss        | 2.02e+08  |
# |    std                | 0.994     |
# |    value_loss         | 6.16e+13  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 411      |
# |    iterations         | 1300     |
# |    time_elapsed       | 15       |
# |    total_timesteps    | 6500     |
# | train/                |          |
# |    entropy_loss       | -28.2    |
# |    explained_variance | 2.38e-07 |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 1299     |
# |    policy_loss        | 2.76e+08 |
# |    std                | 0.994    |
# |    value_loss         | 1e+14    |
# ------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3305758.323064007
# Sharpe:  1.106128035493272
# =================================
# ------------------------------------
# | time/                 |          |
# |    fps                | 412      |
# |    iterations         | 1400     |
# |    time_elapsed       | 16       |
# |    total_timesteps    | 7000     |
# | train/                |          |
# |    entropy_loss       | -28.3    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 1399     |
# |    policy_loss        | 9.83e+07 |
# |    std                | 0.994    |
# |    value_loss         | 1.45e+13 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 416       |
# |    iterations         | 1500      |
# |    time_elapsed       | 18        |
# |    total_timesteps    | 7500      |
# | train/                |           |
# |    entropy_loss       | -28.2     |
# |    explained_variance | -2.38e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 1499      |
# |    policy_loss        | 1.51e+08  |
# |    std                | 0.993     |
# |    value_loss         | 3.19e+13  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 415      |
# |    iterations         | 1600     |
# |    time_elapsed       | 19       |
# |    total_timesteps    | 8000     |
# | train/                |          |
# |    entropy_loss       | -28.2    |
# |    explained_variance | 1.19e-07 |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 1599     |
# |    policy_loss        | 1.83e+08 |
# |    std                | 0.993    |
# |    value_loss         | 4.92e+13 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 407       |
# |    iterations         | 1700      |
# |    time_elapsed       | 20        |
# |    total_timesteps    | 8500      |
# | train/                |           |
# |    entropy_loss       | -28.2     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 1699      |
# |    policy_loss        | 2.28e+08  |
# |    std                | 0.993     |
# |    value_loss         | 7.33e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3236340.559816933
# Sharpe:  1.080256521406161
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 404       |
# |    iterations         | 1800      |
# |    time_elapsed       | 22        |
# |    total_timesteps    | 9000      |
# | train/                |           |
# |    entropy_loss       | -28.2     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 1799      |
# |    policy_loss        | 9.11e+07  |
# |    std                | 0.992     |
# |    value_loss         | 9.95e+12  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 406      |
# |    iterations         | 1900     |
# |    time_elapsed       | 23       |
# |    total_timesteps    | 9500     |
# | train/                |          |
# |    entropy_loss       | -28.2    |
# |    explained_variance | 5.96e-08 |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 1899     |
# |    policy_loss        | 1.04e+08 |
# |    std                | 0.991    |
# |    value_loss         | 1.8e+13  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 396      |
# |    iterations         | 2000     |
# |    time_elapsed       | 25       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -28.2    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 1999     |
# |    policy_loss        | 1.47e+08 |
# |    std                | 0.991    |
# |    value_loss         | 3.87e+13 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 397       |
# |    iterations         | 2100      |
# |    time_elapsed       | 26        |
# |    total_timesteps    | 10500     |
# | train/                |           |
# |    entropy_loss       | -28.2     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 2099      |
# |    policy_loss        | 1.94e+08  |
# |    std                | 0.99      |
# |    value_loss         | 5.26e+13  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 400      |
# |    iterations         | 2200     |
# |    time_elapsed       | 27       |
# |    total_timesteps    | 11000    |
# | train/                |          |
# |    entropy_loss       | -28.2    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 2199     |
# |    policy_loss        | 2.64e+08 |
# |    std                | 0.99     |
# |    value_loss         | 9.1e+13  |
# ------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3138254.0026103077
# Sharpe:  1.0549174719118202
# =================================
# ------------------------------------
# | time/                 |          |
# |    fps                | 401      |
# |    iterations         | 2300     |
# |    time_elapsed       | 28       |
# |    total_timesteps    | 11500    |
# | train/                |          |
# |    entropy_loss       | -28.2    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 2299     |
# |    policy_loss        | 9.93e+07 |
# |    std                | 0.99     |
# |    value_loss         | 1.36e+13 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 404      |
# |    iterations         | 2400     |
# |    time_elapsed       | 29       |
# |    total_timesteps    | 12000    |
# | train/                |          |
# |    entropy_loss       | -28.2    |
# |    explained_variance | 1.79e-07 |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 2399     |
# |    policy_loss        | 1.38e+08 |
# |    std                | 0.99     |
# |    value_loss         | 3.01e+13 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 407      |
# |    iterations         | 2500     |
# |    time_elapsed       | 30       |
# |    total_timesteps    | 12500    |
# | train/                |          |
# |    entropy_loss       | -28.1    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 2499     |
# |    policy_loss        | 1.66e+08 |
# |    std                | 0.989    |
# |    value_loss         | 4.56e+13 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 410      |
# |    iterations         | 2600     |
# |    time_elapsed       | 31       |
# |    total_timesteps    | 13000    |
# | train/                |          |
# |    entropy_loss       | -28.1    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 2599     |
# |    policy_loss        | 2.51e+08 |
# |    std                | 0.988    |
# |    value_loss         | 8.82e+13 |
# ------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3514116.4855714045
# Sharpe:  1.1453547804503474
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 411       |
# |    iterations         | 2700      |
# |    time_elapsed       | 32        |
# |    total_timesteps    | 13500     |
# | train/                |           |
# |    entropy_loss       | -28.1     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 2699      |
# |    policy_loss        | 8.7e+07   |
# |    std                | 0.988     |
# |    value_loss         | 1.24e+13  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 407      |
# |    iterations         | 2800     |
# |    time_elapsed       | 34       |
# |    total_timesteps    | 14000    |
# | train/                |          |
# |    entropy_loss       | -28.1    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 2799     |
# |    policy_loss        | 1.18e+08 |
# |    std                | 0.987    |
# |    value_loss         | 2.34e+13 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 406      |
# |    iterations         | 2900     |
# |    time_elapsed       | 35       |
# |    total_timesteps    | 14500    |
# | train/                |          |
# |    entropy_loss       | -28.1    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 2899     |
# |    policy_loss        | 1.66e+08 |
# |    std                | 0.987    |
# |    value_loss         | 4.38e+13 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 390      |
# |    iterations         | 3000     |
# |    time_elapsed       | 38       |
# |    total_timesteps    | 15000    |
# | train/                |          |
# |    entropy_loss       | -28.1    |
# |    explained_variance | 3.58e-07 |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 2999     |
# |    policy_loss        | 2.01e+08 |
# |    std                | 0.986    |
# |    value_loss         | 6.53e+13 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 384      |
# |    iterations         | 3100     |
# |    time_elapsed       | 40       |
# |    total_timesteps    | 15500    |
# | train/                |          |
# |    entropy_loss       | -28.1    |
# |    explained_variance | 1.79e-07 |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 3099     |
# |    policy_loss        | 2.84e+08 |
# |    std                | 0.985    |
# |    value_loss         | 1.29e+14 |
# ------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3369099.138063982
# Sharpe:  1.1114534462374919
# =================================
# ------------------------------------
# | time/                 |          |
# |    fps                | 379      |
# |    iterations         | 3200     |
# |    time_elapsed       | 42       |
# |    total_timesteps    | 16000    |
# | train/                |          |
# |    entropy_loss       | -28.1    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 3199     |
# |    policy_loss        | 1.01e+08 |
# |    std                | 0.985    |
# |    value_loss         | 1.58e+13 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 379       |
# |    iterations         | 3300      |
# |    time_elapsed       | 43        |
# |    total_timesteps    | 16500     |
# | train/                |           |
# |    entropy_loss       | -28.1     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 3299      |
# |    policy_loss        | 1.53e+08  |
# |    std                | 0.985     |
# |    value_loss         | 3.73e+13  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 379      |
# |    iterations         | 3400     |
# |    time_elapsed       | 44       |
# |    total_timesteps    | 17000    |
# | train/                |          |
# |    entropy_loss       | -28.1    |
# |    explained_variance | 1.19e-07 |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 3399     |
# |    policy_loss        | 2.03e+08 |
# |    std                | 0.984    |
# |    value_loss         | 5.45e+13 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 380      |
# |    iterations         | 3500     |
# |    time_elapsed       | 45       |
# |    total_timesteps    | 17500    |
# | train/                |          |
# |    entropy_loss       | -28      |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 3499     |
# |    policy_loss        | 2.51e+08 |
# |    std                | 0.983    |
# |    value_loss         | 9.75e+13 |
# ------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3396227.416103998
# Sharpe:  1.1163987152344474
# =================================
# ------------------------------------
# | time/                 |          |
# |    fps                | 378      |
# |    iterations         | 3600     |
# |    time_elapsed       | 47       |
# |    total_timesteps    | 18000    |
# | train/                |          |
# |    entropy_loss       | -28      |
# |    explained_variance | 1.79e-07 |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 3599     |
# |    policy_loss        | 9.11e+07 |
# |    std                | 0.982    |
# |    value_loss         | 1.43e+13 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 374       |
# |    iterations         | 3700      |
# |    time_elapsed       | 49        |
# |    total_timesteps    | 18500     |
# | train/                |           |
# |    entropy_loss       | -28       |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 3699      |
# |    policy_loss        | 1.35e+08  |
# |    std                | 0.982     |
# |    value_loss         | 2.82e+13  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 374      |
# |    iterations         | 3800     |
# |    time_elapsed       | 50       |
# |    total_timesteps    | 19000    |
# | train/                |          |
# |    entropy_loss       | -28      |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 3799     |
# |    policy_loss        | 1.73e+08 |
# |    std                | 0.981    |
# |    value_loss         | 5.27e+13 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 372      |
# |    iterations         | 3900     |
# |    time_elapsed       | 52       |
# |    total_timesteps    | 19500    |
# | train/                |          |
# |    entropy_loss       | -28      |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 3899     |
# |    policy_loss        | 2.47e+08 |
# |    std                | 0.981    |
# |    value_loss         | 7.95e+13 |
# ------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3645588.6291018515
# Sharpe:  1.1818515234608884
# =================================
# ------------------------------------
# | time/                 |          |
# |    fps                | 369      |
# |    iterations         | 4000     |
# |    time_elapsed       | 54       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -28      |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 3999     |
# |    policy_loss        | 9.07e+07 |
# |    std                | 0.981    |
# |    value_loss         | 1.17e+13 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 369      |
# |    iterations         | 4100     |
# |    time_elapsed       | 55       |
# |    total_timesteps    | 20500    |
# | train/                |          |
# |    entropy_loss       | -28      |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 4099     |
# |    policy_loss        | 1.2e+08  |
# |    std                | 0.98     |
# |    value_loss         | 2.04e+13 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 368      |
# |    iterations         | 4200     |
# |    time_elapsed       | 57       |
# |    total_timesteps    | 21000    |
# | train/                |          |
# |    entropy_loss       | -28      |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 4199     |
# |    policy_loss        | 1.51e+08 |
# |    std                | 0.98     |
# |    value_loss         | 3.64e+13 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 364       |
# |    iterations         | 4300      |
# |    time_elapsed       | 59        |
# |    total_timesteps    | 21500     |
# | train/                |           |
# |    entropy_loss       | -28       |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 4299      |
# |    policy_loss        | 1.92e+08  |
# |    std                | 0.979     |
# |    value_loss         | 5.42e+13  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 364      |
# |    iterations         | 4400     |
# |    time_elapsed       | 60       |
# |    total_timesteps    | 22000    |
# | train/                |          |
# |    entropy_loss       | -27.9    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 4399     |
# |    policy_loss        | 2.54e+08 |
# |    std                | 0.978    |
# |    value_loss         | 1.07e+14 |
# ------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3381277.1650072387
# Sharpe:  1.1188819866923658
# =================================
# ------------------------------------
# | time/                 |          |
# |    fps                | 364      |
# |    iterations         | 4500     |
# |    time_elapsed       | 61       |
# |    total_timesteps    | 22500    |
# | train/                |          |
# |    entropy_loss       | -27.9    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 4499     |
# |    policy_loss        | 1.06e+08 |
# |    std                | 0.978    |
# |    value_loss         | 1.6e+13  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 366      |
# |    iterations         | 4600     |
# |    time_elapsed       | 62       |
# |    total_timesteps    | 23000    |
# | train/                |          |
# |    entropy_loss       | -27.9    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 4599     |
# |    policy_loss        | 1.44e+08 |
# |    std                | 0.977    |
# |    value_loss         | 3.38e+13 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 367      |
# |    iterations         | 4700     |
# |    time_elapsed       | 63       |
# |    total_timesteps    | 23500    |
# | train/                |          |
# |    entropy_loss       | -27.9    |
# |    explained_variance | 1.19e-07 |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 4699     |
# |    policy_loss        | 1.64e+08 |
# |    std                | 0.977    |
# |    value_loss         | 5.36e+13 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 368      |
# |    iterations         | 4800     |
# |    time_elapsed       | 65       |
# |    total_timesteps    | 24000    |
# | train/                |          |
# |    entropy_loss       | -27.9    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 4799     |
# |    policy_loss        | 2.38e+08 |
# |    std                | 0.976    |
# |    value_loss         | 9.07e+13 |
# ------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3618950.1873518904
# Sharpe:  1.174596215897652
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 366       |
# |    iterations         | 4900      |
# |    time_elapsed       | 66        |
# |    total_timesteps    | 24500     |
# | train/                |           |
# |    entropy_loss       | -27.9     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 4899      |
# |    policy_loss        | 6.98e+07  |
# |    std                | 0.976     |
# |    value_loss         | 9.54e+12  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 366      |
# |    iterations         | 5000     |
# |    time_elapsed       | 68       |
# |    total_timesteps    | 25000    |
# | train/                |          |
# |    entropy_loss       | -27.9    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 4999     |
# |    policy_loss        | 1.2e+08  |
# |    std                | 0.976    |
# |    value_loss         | 2.07e+13 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 367      |
# |    iterations         | 5100     |
# |    time_elapsed       | 69       |
# |    total_timesteps    | 25500    |
# | train/                |          |
# |    entropy_loss       | -27.9    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 5099     |
# |    policy_loss        | 1.82e+08 |
# |    std                | 0.976    |
# |    value_loss         | 4.49e+13 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 367      |
# |    iterations         | 5200     |
# |    time_elapsed       | 70       |
# |    total_timesteps    | 26000    |
# | train/                |          |
# |    entropy_loss       | -27.9    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 5199     |
# |    policy_loss        | 2.04e+08 |
# |    std                | 0.976    |
# |    value_loss         | 6.43e+13 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 368       |
# |    iterations         | 5300      |
# |    time_elapsed       | 71        |
# |    total_timesteps    | 26500     |
# | train/                |           |
# |    entropy_loss       | -27.9     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 5299      |
# |    policy_loss        | 2.57e+08  |
# |    std                | 0.976     |
# |    value_loss         | 1.21e+14  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3553359.3317767917
# Sharpe:  1.157057527014967
# =================================
# ------------------------------------
# | time/                 |          |
# |    fps                | 367      |
# |    iterations         | 5400     |
# |    time_elapsed       | 73       |
# |    total_timesteps    | 27000    |
# | train/                |          |
# |    entropy_loss       | -27.9    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 5399     |
# |    policy_loss        | 9.71e+07 |
# |    std                | 0.975    |
# |    value_loss         | 1.35e+13 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 368      |
# |    iterations         | 5500     |
# |    time_elapsed       | 74       |
# |    total_timesteps    | 27500    |
# | train/                |          |
# |    entropy_loss       | -27.8    |
# |    explained_variance | 1.19e-07 |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 5499     |
# |    policy_loss        | 1.45e+08 |
# |    std                | 0.974    |
# |    value_loss         | 3.26e+13 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 369      |
# |    iterations         | 5600     |
# |    time_elapsed       | 75       |
# |    total_timesteps    | 28000    |
# | train/                |          |
# |    entropy_loss       | -27.8    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 5599     |
# |    policy_loss        | 1.79e+08 |
# |    std                | 0.973    |
# |    value_loss         | 5.45e+13 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 370      |
# |    iterations         | 5700     |
# |    time_elapsed       | 76       |
# |    total_timesteps    | 28500    |
# | train/                |          |
# |    entropy_loss       | -27.8    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 5699     |
# |    policy_loss        | 2.49e+08 |
# |    std                | 0.973    |
# |    value_loss         | 8.86e+13 |
# ------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3490378.4403543035
# Sharpe:  1.1368821845811499
# =================================
# ------------------------------------
# | time/                 |          |
# |    fps                | 371      |
# |    iterations         | 5800     |
# |    time_elapsed       | 78       |
# |    total_timesteps    | 29000    |
# | train/                |          |
# |    entropy_loss       | -27.8    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 5799     |
# |    policy_loss        | 8.8e+07  |
# |    std                | 0.972    |
# |    value_loss         | 1.27e+13 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 371      |
# |    iterations         | 5900     |
# |    time_elapsed       | 79       |
# |    total_timesteps    | 29500    |
# | train/                |          |
# |    entropy_loss       | -27.8    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 5899     |
# |    policy_loss        | 1.23e+08 |
# |    std                | 0.971    |
# |    value_loss         | 2.5e+13  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 372      |
# |    iterations         | 6000     |
# |    time_elapsed       | 80       |
# |    total_timesteps    | 30000    |
# | train/                |          |
# |    entropy_loss       | -27.8    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 5999     |
# |    policy_loss        | 1.7e+08  |
# |    std                | 0.97     |
# |    value_loss         | 5.07e+13 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 372      |
# |    iterations         | 6100     |
# |    time_elapsed       | 81       |
# |    total_timesteps    | 30500    |
# | train/                |          |
# |    entropy_loss       | -27.8    |
# |    explained_variance | 1.79e-07 |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 6099     |
# |    policy_loss        | 2.47e+08 |
# |    std                | 0.97     |
# |    value_loss         | 7.83e+13 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 373      |
# |    iterations         | 6200     |
# |    time_elapsed       | 82       |
# |    total_timesteps    | 31000    |
# | train/                |          |
# |    entropy_loss       | -27.8    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 6199     |
# |    policy_loss        | 3.32e+08 |
# |    std                | 0.97     |
# |    value_loss         | 1.65e+14 |
# ------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3832058.399141147
# Sharpe:  1.2249112364615355
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 374       |
# |    iterations         | 6300      |
# |    time_elapsed       | 84        |
# |    total_timesteps    | 31500     |
# | train/                |           |
# |    entropy_loss       | -27.7     |
# |    explained_variance | -2.38e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 6299      |
# |    policy_loss        | 9.37e+07  |
# |    std                | 0.969     |
# |    value_loss         | 1.54e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 375       |
# |    iterations         | 6400      |
# |    time_elapsed       | 85        |
# |    total_timesteps    | 32000     |
# | train/                |           |
# |    entropy_loss       | -27.7     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 6399      |
# |    policy_loss        | 1.51e+08  |
# |    std                | 0.969     |
# |    value_loss         | 3.75e+13  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 376      |
# |    iterations         | 6500     |
# |    time_elapsed       | 86       |
# |    total_timesteps    | 32500    |
# | train/                |          |
# |    entropy_loss       | -27.7    |
# |    explained_variance | 2.38e-07 |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 6499     |
# |    policy_loss        | 2.02e+08 |
# |    std                | 0.968    |
# |    value_loss         | 5.48e+13 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 377      |
# |    iterations         | 6600     |
# |    time_elapsed       | 87       |
# |    total_timesteps    | 33000    |
# | train/                |          |
# |    entropy_loss       | -27.7    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 6599     |
# |    policy_loss        | 2.46e+08 |
# |    std                | 0.967    |
# |    value_loss         | 9.6e+13  |
# ------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3381415.609405836
# Sharpe:  1.1113934366532525
# =================================
# ------------------------------------
# | time/                 |          |
# |    fps                | 375      |
# |    iterations         | 6700     |
# |    time_elapsed       | 89       |
# |    total_timesteps    | 33500    |
# | train/                |          |
# |    entropy_loss       | -27.7    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 6699     |
# |    policy_loss        | 9.76e+07 |
# |    std                | 0.967    |
# |    value_loss         | 1.51e+13 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 374      |
# |    iterations         | 6800     |
# |    time_elapsed       | 90       |
# |    total_timesteps    | 34000    |
# | train/                |          |
# |    entropy_loss       | -27.7    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 6799     |
# |    policy_loss        | 1.26e+08 |
# |    std                | 0.967    |
# |    value_loss         | 2.92e+13 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 375      |
# |    iterations         | 6900     |
# |    time_elapsed       | 91       |
# |    total_timesteps    | 34500    |
# | train/                |          |
# |    entropy_loss       | -27.7    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 6899     |
# |    policy_loss        | 1.9e+08  |
# |    std                | 0.967    |
# |    value_loss         | 5.55e+13 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 376      |
# |    iterations         | 7000     |
# |    time_elapsed       | 92       |
# |    total_timesteps    | 35000    |
# | train/                |          |
# |    entropy_loss       | -27.7    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 6999     |
# |    policy_loss        | 2.22e+08 |
# |    std                | 0.966    |
# |    value_loss         | 7.65e+13 |
# ------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3514373.260051781
# Sharpe:  1.1442739266325872
# =================================
# ------------------------------------
# | time/                 |          |
# |    fps                | 377      |
# |    iterations         | 7100     |
# |    time_elapsed       | 94       |
# |    total_timesteps    | 35500    |
# | train/                |          |
# |    entropy_loss       | -27.7    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 7099     |
# |    policy_loss        | 8.77e+07 |
# |    std                | 0.965    |
# |    value_loss         | 1.14e+13 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 377      |
# |    iterations         | 7200     |
# |    time_elapsed       | 95       |
# |    total_timesteps    | 36000    |
# | train/                |          |
# |    entropy_loss       | -27.7    |
# |    explained_variance | 1.19e-07 |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 7199     |
# |    policy_loss        | 1.14e+08 |
# |    std                | 0.966    |
# |    value_loss         | 2.05e+13 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 378      |
# |    iterations         | 7300     |
# |    time_elapsed       | 96       |
# |    total_timesteps    | 36500    |
# | train/                |          |
# |    entropy_loss       | -27.7    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 7299     |
# |    policy_loss        | 1.68e+08 |
# |    std                | 0.966    |
# |    value_loss         | 3.91e+13 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 379       |
# |    iterations         | 7400      |
# |    time_elapsed       | 97        |
# |    total_timesteps    | 37000     |
# | train/                |           |
# |    entropy_loss       | -27.7     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 7399      |
# |    policy_loss        | 1.86e+08  |
# |    std                | 0.965     |
# |    value_loss         | 5.76e+13  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 379      |
# |    iterations         | 7500     |
# |    time_elapsed       | 98       |
# |    total_timesteps    | 37500    |
# | train/                |          |
# |    entropy_loss       | -27.7    |
# |    explained_variance | 1.19e-07 |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 7499     |
# |    policy_loss        | 2.72e+08 |
# |    std                | 0.965    |
# |    value_loss         | 1.18e+14 |
# ------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3567956.4055620357
# Sharpe:  1.1532910695069298
# =================================
# ------------------------------------
# | time/                 |          |
# |    fps                | 379      |
# |    iterations         | 7600     |
# |    time_elapsed       | 100      |
# |    total_timesteps    | 38000    |
# | train/                |          |
# |    entropy_loss       | -27.7    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 7599     |
# |    policy_loss        | 1.06e+08 |
# |    std                | 0.966    |
# |    value_loss         | 1.63e+13 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 379       |
# |    iterations         | 7700      |
# |    time_elapsed       | 101       |
# |    total_timesteps    | 38500     |
# | train/                |           |
# |    entropy_loss       | -27.7     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 7699      |
# |    policy_loss        | 1.59e+08  |
# |    std                | 0.965     |
# |    value_loss         | 3.39e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 380       |
# |    iterations         | 7800      |
# |    time_elapsed       | 102       |
# |    total_timesteps    | 39000     |
# | train/                |           |
# |    entropy_loss       | -27.7     |
# |    explained_variance | -2.38e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 7799      |
# |    policy_loss        | 1.9e+08   |
# |    std                | 0.965     |
# |    value_loss         | 5.62e+13  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 381      |
# |    iterations         | 7900     |
# |    time_elapsed       | 103      |
# |    total_timesteps    | 39500    |
# | train/                |          |
# |    entropy_loss       | -27.6    |
# |    explained_variance | 1.19e-07 |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 7899     |
# |    policy_loss        | 2.2e+08  |
# |    std                | 0.964    |
# |    value_loss         | 8.6e+13  |
# ------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3666068.9336377303
# Sharpe:  1.1705863803915642
# =================================
# ------------------------------------
# | time/                 |          |
# |    fps                | 379      |
# |    iterations         | 8000     |
# |    time_elapsed       | 105      |
# |    total_timesteps    | 40000    |
# | train/                |          |
# |    entropy_loss       | -27.6    |
# |    explained_variance | 5.96e-08 |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 7999     |
# |    policy_loss        | 7.98e+07 |
# |    std                | 0.964    |
# |    value_loss         | 9.56e+12 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 379      |
# |    iterations         | 8100     |
# |    time_elapsed       | 106      |
# |    total_timesteps    | 40500    |
# | train/                |          |
# |    entropy_loss       | -27.6    |
# |    explained_variance | 5.96e-08 |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 8099     |
# |    policy_loss        | 1.17e+08 |
# |    std                | 0.964    |
# |    value_loss         | 2.06e+13 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 380      |
# |    iterations         | 8200     |
# |    time_elapsed       | 107      |
# |    total_timesteps    | 41000    |
# | train/                |          |
# |    entropy_loss       | -27.6    |
# |    explained_variance | 5.96e-08 |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 8199     |
# |    policy_loss        | 1.6e+08  |
# |    std                | 0.964    |
# |    value_loss         | 4.49e+13 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 380      |
# |    iterations         | 8300     |
# |    time_elapsed       | 108      |
# |    total_timesteps    | 41500    |
# | train/                |          |
# |    entropy_loss       | -27.6    |
# |    explained_variance | 1.19e-07 |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 8299     |
# |    policy_loss        | 2e+08    |
# |    std                | 0.963    |
# |    value_loss         | 6.52e+13 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 380      |
# |    iterations         | 8400     |
# |    time_elapsed       | 110      |
# |    total_timesteps    | 42000    |
# | train/                |          |
# |    entropy_loss       | -27.6    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 8399     |
# |    policy_loss        | 2.61e+08 |
# |    std                | 0.963    |
# |    value_loss         | 1.15e+14 |
# ------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3444553.985856717
# Sharpe:  1.1119408823786168
# =================================
# ------------------------------------
# | time/                 |          |
# |    fps                | 379      |
# |    iterations         | 8500     |
# |    time_elapsed       | 111      |
# |    total_timesteps    | 42500    |
# | train/                |          |
# |    entropy_loss       | -27.6    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 8499     |
# |    policy_loss        | 9.54e+07 |
# |    std                | 0.962    |
# |    value_loss         | 1.3e+13  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 379      |
# |    iterations         | 8600     |
# |    time_elapsed       | 113      |
# |    total_timesteps    | 43000    |
# | train/                |          |
# |    entropy_loss       | -27.6    |
# |    explained_variance | 1.19e-07 |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 8599     |
# |    policy_loss        | 1.36e+08 |
# |    std                | 0.961    |
# |    value_loss         | 3.19e+13 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 380      |
# |    iterations         | 8700     |
# |    time_elapsed       | 114      |
# |    total_timesteps    | 43500    |
# | train/                |          |
# |    entropy_loss       | -27.6    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 8699     |
# |    policy_loss        | 1.75e+08 |
# |    std                | 0.961    |
# |    value_loss         | 4.92e+13 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 380       |
# |    iterations         | 8800      |
# |    time_elapsed       | 115       |
# |    total_timesteps    | 44000     |
# | train/                |           |
# |    entropy_loss       | -27.6     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 8799      |
# |    policy_loss        | 2.35e+08  |
# |    std                | 0.961     |
# |    value_loss         | 8.33e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3309456.2007761137
# Sharpe:  1.0791024183641753
# =================================
# ------------------------------------
# | time/                 |          |
# |    fps                | 380      |
# |    iterations         | 8900     |
# |    time_elapsed       | 116      |
# |    total_timesteps    | 44500    |
# | train/                |          |
# |    entropy_loss       | -27.6    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 8899     |
# |    policy_loss        | 9.5e+07  |
# |    std                | 0.961    |
# |    value_loss         | 1.22e+13 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 381      |
# |    iterations         | 9000     |
# |    time_elapsed       | 118      |
# |    total_timesteps    | 45000    |
# | train/                |          |
# |    entropy_loss       | -27.6    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 8999     |
# |    policy_loss        | 1.23e+08 |
# |    std                | 0.96     |
# |    value_loss         | 2.44e+13 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 381      |
# |    iterations         | 9100     |
# |    time_elapsed       | 119      |
# |    total_timesteps    | 45500    |
# | train/                |          |
# |    entropy_loss       | -27.6    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 9099     |
# |    policy_loss        | 1.67e+08 |
# |    std                | 0.961    |
# |    value_loss         | 4.65e+13 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 381       |
# |    iterations         | 9200      |
# |    time_elapsed       | 120       |
# |    total_timesteps    | 46000     |
# | train/                |           |
# |    entropy_loss       | -27.6     |
# |    explained_variance | -2.38e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 9199      |
# |    policy_loss        | 2.14e+08  |
# |    std                | 0.961     |
# |    value_loss         | 6.62e+13  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 381      |
# |    iterations         | 9300     |
# |    time_elapsed       | 121      |
# |    total_timesteps    | 46500    |
# | train/                |          |
# |    entropy_loss       | -27.6    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 9299     |
# |    policy_loss        | 2.65e+08 |
# |    std                | 0.961    |
# |    value_loss         | 1.29e+14 |
# ------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3391035.8942683903
# Sharpe:  1.0977347424149428
# =================================
# ------------------------------------
# | time/                 |          |
# |    fps                | 381      |
# |    iterations         | 9400     |
# |    time_elapsed       | 123      |
# |    total_timesteps    | 47000    |
# | train/                |          |
# |    entropy_loss       | -27.6    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 9399     |
# |    policy_loss        | 9.4e+07  |
# |    std                | 0.961    |
# |    value_loss         | 1.45e+13 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 379       |
# |    iterations         | 9500      |
# |    time_elapsed       | 125       |
# |    total_timesteps    | 47500     |
# | train/                |           |
# |    entropy_loss       | -27.6     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 9499      |
# |    policy_loss        | 1.58e+08  |
# |    std                | 0.96      |
# |    value_loss         | 3.85e+13  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 378      |
# |    iterations         | 9600     |
# |    time_elapsed       | 126      |
# |    total_timesteps    | 48000    |
# | train/                |          |
# |    entropy_loss       | -27.6    |
# |    explained_variance | 1.19e-07 |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 9599     |
# |    policy_loss        | 1.81e+08 |
# |    std                | 0.96     |
# |    value_loss         | 5.67e+13 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 379      |
# |    iterations         | 9700     |
# |    time_elapsed       | 127      |
# |    total_timesteps    | 48500    |
# | train/                |          |
# |    entropy_loss       | -27.6    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 9699     |
# |    policy_loss        | 3.05e+08 |
# |    std                | 0.96     |
# |    value_loss         | 1.06e+14 |
# ------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3500860.7554526576
# Sharpe:  1.1317678165090992
# =================================
# ------------------------------------
# | time/                 |          |
# |    fps                | 378      |
# |    iterations         | 9800     |
# |    time_elapsed       | 129      |
# |    total_timesteps    | 49000    |
# | train/                |          |
# |    entropy_loss       | -27.6    |
# |    explained_variance | 1.19e-07 |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 9799     |
# |    policy_loss        | 9.32e+07 |
# |    std                | 0.96     |
# |    value_loss         | 1.31e+13 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 378      |
# |    iterations         | 9900     |
# |    time_elapsed       | 130      |
# |    total_timesteps    | 49500    |
# | train/                |          |
# |    entropy_loss       | -27.6    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 9899     |
# |    policy_loss        | 1.22e+08 |
# |    std                | 0.96     |
# |    value_loss         | 2.39e+13 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 379      |
# |    iterations         | 10000    |
# |    time_elapsed       | 131      |
# |    total_timesteps    | 50000    |
# | train/                |          |
# |    entropy_loss       | -27.5    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 9999     |
# |    policy_loss        | 1.76e+08 |
# |    std                | 0.959    |
# |    value_loss         | 4.84e+13 |
# ------------------------------------

# %%
# A2C Train Model
e_trade_gym = StockPortfolioEnv(df = train_df, **env_kwargs)
env_trade, obs_trade = e_trade_gym.get_sb_env()

a2c_train_daily_return, a2c_train_weights = DRLAgent.DRL_prediction(model=trained_a2c,
                        test_data = train_df,
                        test_env = env_trade,
                        test_obs = obs_trade)
# Out:
# =================================
# begin_total_asset:1000000
# end_total_asset:3486836.2855546037
# Sharpe:  1.140399454061648
# =================================

# %%
# A2C Test Model
e_trade_gym = StockPortfolioEnv(df = test_df, **env_kwargs)
env_trade, obs_trade = e_trade_gym.get_sb_env()

a2c_test_daily_return, a2c_test_weights = DRLAgent.DRL_prediction(model=trained_a2c,
                        test_data = test_df,
                        test_env = env_trade,
                        test_obs = obs_trade)
# Out:
# c:\Users\Usuario\Documents\deep_learning_asset_portfolio_management\env\lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# =================================
# begin_total_asset:1000000
# end_total_asset:1312209.4334361842
# Sharpe:  0.6337230352867573
# =================================

# %%
agent = DRLAgent(env = env_train)
PPO_PARAMS = {
    "n_steps": 2048,
    "ent_coef": 0.005,
    "learning_rate": 0.0001,
    "batch_size": 128,
}
model_ppo = agent.get_model("ppo",model_kwargs = PPO_PARAMS)
# Out:
# {'n_steps': 2048, 'ent_coef': 0.005, 'learning_rate': 0.0001, 'batch_size': 128}
# Using cpu device

# %%
trained_ppo = agent.train_model(model=model_ppo, 
                             tb_log_name='ppo',
                             total_timesteps=50000)

# %%
# PPO Train Model
e_trade_gym = StockPortfolioEnv(df = train_df, **env_kwargs)
env_trade, obs_trade = e_trade_gym.get_sb_env()

ppo_train_daily_return, ppo_train_weights = DRLAgent.DRL_prediction(model=trained_ppo,
                        test_data = train_df,
                        test_env = env_trade,
                        test_obs = obs_trade)

# %%
# PPO Test Model
e_trade_gym = StockPortfolioEnv(df = test_df, **env_kwargs)
env_trade, obs_trade = e_trade_gym.get_sb_env()

ppo_test_daily_return, ppo_test_weights = DRLAgent.DRL_prediction(model=trained_ppo,
                        test_data = test_df,
                        test_env = env_trade,
                        test_obs = obs_trade)

# %%
############################### asi hay que operar en produccion #########################
env_kwargs_test = {
    "hmax": 500, 
    "initial_amount": 5000, 
    "transaction_cost_pct": 0.001, 
    "state_space": state_space, 
    "stock_dim": stock_dimension, 
    "tech_indicator_list": tech_indicator_list, 
    "action_space": stock_dimension, 
    "reward_scaling": 0,
    'initial_weights': [1/stock_dimension]*stock_dimension
}

e_trade_gym = StockPortfolioEnv(df = test_df, **env_kwargs_test)
env_trade, obs_trade = e_trade_gym.get_sb_env()

ppo_test_daily_return, ppo_test_weights = DRLAgent.DRL_prediction(model=trained_ppo,
                        test_data = test_df,
                        test_env = env_trade,
                        test_obs = obs_trade)

# %%
agent = DRLAgent(env = env_train)
DDPG_PARAMS = {"batch_size": 128, "buffer_size": 50000, "learning_rate": 0.001}
model_ddpg = agent.get_model("ddpg",model_kwargs = DDPG_PARAMS)
# Out:
# {'batch_size': 128, 'buffer_size': 50000, 'learning_rate': 0.001}
# Using cpu device

# %%
trained_ddpg = agent.train_model(model=model_ddpg, 
                             tb_log_name='ddpg',
                             total_timesteps=50000)
# Out:
# Logging to tensorboard_log/ddpg\ddpg_1
# =================================
# begin_total_asset:1000000
# end_total_asset:3422869.824724422
# Sharpe:  1.1274960483557201
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:3439595.4824811267
# Sharpe:  1.1009502911626945
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:3439595.4824811267
# Sharpe:  1.1009502911626945
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:3439595.4824811267
# Sharpe:  1.1009502911626945
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 44        |
# |    time_elapsed    | 200       |
# |    total_timesteps | 8860      |
# | train/             |           |
# |    actor_loss      | -4.97e+07 |
# |    critic_loss     | 1.86e+12  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 6645      |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3439595.4824811267
# Sharpe:  1.1009502911626945
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:3439595.4824811267
# Sharpe:  1.1009502911626945
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:3439595.4824811267
# Sharpe:  1.1009502911626945
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:3439595.4824811267
# Sharpe:  1.1009502911626945
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 8         |
# |    fps             | 35        |
# |    time_elapsed    | 502       |
# |    total_timesteps | 17720     |
# | train/             |           |
# |    actor_loss      | -1.01e+08 |
# |    critic_loss     | 9.19e+12  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 15505     |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3439595.4824811267
# Sharpe:  1.1009502911626945
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:3439595.4824811267
# Sharpe:  1.1009502911626945
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:3439595.4824811267
# Sharpe:  1.1009502911626945
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:3439595.4824811267
# Sharpe:  1.1009502911626945
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 12        |
# |    fps             | 35        |
# |    time_elapsed    | 741       |
# |    total_timesteps | 26580     |
# | train/             |           |
# |    actor_loss      | -1.34e+08 |
# |    critic_loss     | 1.56e+13  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 24365     |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3439595.4824811267
# Sharpe:  1.1009502911626945
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:3439595.4824811267
# Sharpe:  1.1009502911626945
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:3439595.4824811267
# Sharpe:  1.1009502911626945
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:3439595.4824811267
# Sharpe:  1.1009502911626945
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 16        |
# |    fps             | 35        |
# |    time_elapsed    | 996       |
# |    total_timesteps | 35440     |
# | train/             |           |
# |    actor_loss      | -1.54e+08 |
# |    critic_loss     | 1.99e+13  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 33225     |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3439595.4824811267
# Sharpe:  1.1009502911626945
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:3439595.4824811267
# Sharpe:  1.1009502911626945
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:3439595.4824811267
# Sharpe:  1.1009502911626945
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:3439595.4824811267
# Sharpe:  1.1009502911626945
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 20        |
# |    fps             | 36        |
# |    time_elapsed    | 1221      |
# |    total_timesteps | 44300     |
# | train/             |           |
# |    actor_loss      | -1.68e+08 |
# |    critic_loss     | 2.5e+13   |
# |    learning_rate   | 0.001     |
# |    n_updates       | 42085     |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3439595.4824811267
# Sharpe:  1.1009502911626945
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:3439595.4824811267
# Sharpe:  1.1009502911626945
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:3439595.4824811267
# Sharpe:  1.1009502911626945
# =================================

# %%
# DDPG Test Model
e_trade_gym = StockPortfolioEnv(df = test_df, **env_kwargs)
env_trade, obs_trade = e_trade_gym.get_sb_env()

ddpg_test_daily_return, ddpg_test_weights = DRLAgent.DRL_prediction(model=trained_ddpg,
                        test_data = test_df,
                        test_env = env_trade,
                        test_obs = obs_trade)
# Out:
# c:\Users\Usuario\Documents\deep_learning_asset_portfolio_management\env\lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# =================================
# begin_total_asset:1000000
# end_total_asset:1315830.847142868
# Sharpe:  0.6394863792036135
# =================================

# %%
a2c_test_portfolio = a2c_test_daily_return.copy()
a2c_test_returns = a2c_test_daily_return.copy()

ppo_test_portfolio = ppo_test_daily_return.copy()
ppo_test_returns = ppo_test_daily_return.copy()

ddpg_test_portfolio = ddpg_test_daily_return.copy()
ddpg_test_returns = ddpg_test_daily_return.copy()

# %%
a2c_test_cum_returns = (1 + a2c_test_returns['daily_return']).cumprod()
a2c_test_cum_returns.name = 'Portfolio 1: a2c Model'

# %%
ppo_test_cum_returns = (1 + ppo_test_returns['daily_return']).cumprod()
ppo_test_cum_returns.name = 'Portfolio 2: ppo Model'

# %%
ddpg_test_cum_returns = (1 + ddpg_test_returns['daily_return']).cumprod()
ddpg_test_cum_returns.name = 'Portfolio 3: ddpg Model'

# %%
import matplotlib.pylab as plt

# %%
# Plot the culmulative returns of the portfolios
fig, ax = plt.subplots(figsize=(10,4))

a2c_test_cum_returns.plot(ax=ax, color='darkorange', alpha=.4)
ppo_test_cum_returns.plot(ax=ax, color='green', alpha=.4)
ddpg_test_cum_returns.plot(ax=ax, color='purple', alpha=.4)
plt.legend(loc="best")
plt.grid(True)
ax.set_ylabel("cummulative return")
ax.set_title("Backtest based on the data from 2018-10-19 to 2020-12-30", fontsize=14)
fig.savefig('results/back_test_on_test_data.png')

# %%
# from backtest import BackTestStats, BaselineStats, BackTestPlot, backtest_strat, baseline_strat
# from backtest import backtest_strat
from pyfolio import timeseries

# %%
def backtest_strat(df):
    strategy_ret = df.copy()
    strategy_ret["date"] = pd.to_datetime(strategy_ret["date"])
    strategy_ret.set_index("date", drop=False, inplace=True)
    strategy_ret.index = strategy_ret.index.tz_localize("UTC")
    del strategy_ret["date"]
    ts = pd.Series(strategy_ret["daily_return"].values, index=strategy_ret.index)
    return ts

# %%
def portfolio_stats(portfolio_returns):
    # Pass the returns into a dataframe
    port_rets_df = pd.DataFrame(portfolio_returns)
    port_rets_df = port_rets_df.reset_index()
    port_rets_df.columns = ['date','daily_return']
    
    #Use the FinRL Library to get the Portfolio Returns
    #This makes use of the Pyfolio Library
    
    DRL_strat = backtest_strat(port_rets_df)
    perf_func = timeseries.perf_stats 
    perf_stats_all = perf_func( returns=DRL_strat, 
                                  factor_returns=DRL_strat, 
                                    positions=None, transactions=None, turnover_denom="AGB")
    perf_stats_all = pd.DataFrame( perf_stats_all)
    perf_stats_all.columns = ['Statistic']
    return perf_stats_all

# %%
# Get the Portfolio Statistics for all the portfolios
portfolios_returns_dict = {
                          'a2c Model': a2c_test_returns['daily_return'],
                          'ppo Model': ppo_test_returns['daily_return'],
                          'ddpg Model': ddpg_test_returns['daily_return']}

portfolios_stats = pd.DataFrame()
for i,j in portfolios_returns_dict.items():
    port_stats = portfolio_stats(j)
    portfolios_stats[i] = port_stats['Statistic']

# %%
portfolios_stats
# Out:
#                      a2c Model  ppo Model  ddpg Model
# Annual return         0.132064   0.141418    0.133489
# Cumulative returns    0.312209   0.336077    0.315831
# Annual volatility     0.242217   0.237239    0.241803
# Sharpe ratio          0.633723   0.676522    0.639486
# Calmar ratio          0.411601   0.464482    0.440018
# Stability             0.396161   0.499613    0.495449
# Max drawdown         -0.320855  -0.304465   -0.303372
# Omega ratio           1.143112   1.152735    1.143115
# Sortino ratio         0.892366   0.958384    0.905397
# Skew                 -0.367429  -0.259498   -0.290084
# Kurtosis             12.722935  12.069880   11.636311
# Tail ratio            0.837221   0.774527    0.834375
# Daily value at risk  -0.029907  -0.029252   -0.029851
# Alpha                 0.000000   0.000000    0.000000
# Beta                  1.000000   1.000000    1.000000

# %%
ppo_test_returns = ppo_test_returns.set_index('date')
ddpg_test_returns = ddpg_test_returns.set_index('date')

# %%
# Getting the best performing portfolio

ps_cum = [a2c_test_cum_returns, ppo_test_cum_returns,ddpg_test_cum_returns]
ps = [a2c_test_returns['daily_return'], ppo_test_returns['daily_return'], ddpg_test_returns['daily_return']]

final_return = []
for p in ps_cum:
    final_return.append(p.iloc[-1])
    
id_ = np.argmax(final_return)
best_p = ps[id_]
best_p.name = (ps_cum[id_]).name 

print("Best portfolio: ",  best_p.name)
print("Final cumulative return: {:.2f} ".format(final_return[id_]))
# Out:
# Best portfolio:  Portfolio 2: ppo Model
# Final cumulative return: 1.34

# %%
env_kwargs_test = {
    "hmax": 500, 
    "initial_amount": 5000, 
    "transaction_cost_pct": 0.001, 
    "state_space": state_space, 
    "stock_dim": stock_dimension, 
    "tech_indicator_list": tech_indicator_list, 
    "action_space": stock_dimension, 
    "reward_scaling": 0,
    'initial_weights': [1/stock_dimension]*stock_dimension
}

e_trade_gym = StockPortfolioEnv(df = test_df, **env_kwargs_test)
env_trade, obs_trade = e_trade_gym.get_sb_env()

ppo_test_daily_return, ppo_test_weights = DRLAgent.DRL_prediction(model=trained_ppo,
                        test_data = test_df,
                        test_env = env_trade,
                        test_obs = obs_trade)

# %%
type(trained_ppo)
# Out:
# stable_baselines3.ppo.ppo.PPO

# %%
import pickle
pickle.dump(test_df, open('rl_models_test_data.pkl', 'wb'))

# %%
trained_a2c.save("trained_a2c_model.zip")

# %%
trained_ppo.save("trained_ppo_model.zip")

# %%
trained_ddpg.save("trained_ddpg_model.zip")
